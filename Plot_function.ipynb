# %% [markdown]
# <a href="https://colab.research.google.com/github/gregorimaia/Engenharia_Aeroespacial/blob/main/Plot_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *
from sympy.plotting import *
import math
# %matplotlib inline
init_printing(pretty_print=true)    #Para imprimir a função corretamente estruturada.
x = Symbol('x')
plot(320*ln((1+x)/(0.05+x))+(450*ln((1+x)/(0.07+x))))
